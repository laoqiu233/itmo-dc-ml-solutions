# %% [markdown]
# ![image.png](data:image/png;base64,...)
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Задание легче всего сделать в вольфраме
#
# Вам нужно составить систему уравнений по типу моей: ![image.png](data:image/png;base64,...)
#
# Внимательно следите какое число куда идет. Мой вариант представлен выше. Gamma дана в варианте:![image.png](data:image/png;base64,...).
#
# Дальше решаем систему в вольфраме(или еще где-то) и получаем ответ(обведен красным)
